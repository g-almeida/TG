# %% [markdown]
# # Dados - Q1

# %%
import requests
import numpy as np
import pandas as pd
import datetime
import json
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import math

# %% [markdown]
# ## Obtendo:
# Lista das estações automáticas:

# %%
# Buscando via API - INMET
aut_List = requests.get('https://apitempo.inmet.gov.br/estacoes/T')

# %%
# Listando os dados coletados:

# Lista de dicionários informativos de cada estação
dicts_list = []

# Lista dos nomes das estações
est_names = []

# Lista dos códigos das estações
est_codes = []

for estacao in aut_List.json():
    estDict = dict(estacao)
    est_names.append(estDict['DC_NOME'])
    est_codes.append(estDict['CD_ESTACAO'])
    dicts_list.append(estDict)

# %%
# criação do DataFrame
df_names = pd.DataFrame({'Name':[],'Code':[]}) 
for cada in dicts_list:
    df_names = df_names.append({'Name':cada['DC_NOME'], 'Code':cada['CD_ESTACAO']}, ignore_index=True)

df_names.to_csv('listaEstacoes.csv')
df_names
# Out:
#                      Name  Code
# 0                ABROLHOS  A422
# 1                  ACARAU  A360
# 2          AFONSO CLAUDIO  A657
# 3                AGUA BOA  A908
# 4              AGUA CLARA  A756
# ..                    ...   ...
# 600  VITORIA DA CONQUISTA  A414
# 601           VOTUPORANGA  A729
# 602               XANXERE  A858
# 603              XINGUARA  A247
# 604               ZE DOCA  A255
#
# [605 rows x 2 columns]

# %% [markdown]
# Série de 14 dias:

# %%
# Buscando os 14 dias (2021-09-16 até 2021-09-30)
# Como a API exige o código da estação, será feita uma iteração com a lista obtida anteriormente (est_codes) 
list14_days = []
dict_14days = {} # dicionário com todas as estações e seus respectivos dados no intervalo
for code in est_codes:
    data14 = requests.get('https://apitempo.inmet.gov.br/estacao/diaria/2021-09-16/2021-09-30/'+code)
    dict_14days.update({code:data14.json()})
    list14_days.append(data14.json())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-ddba331b7707> in <module>
#       4 dict_14days = {} # dicionário com todas as estações e seus respectivos dados no intervalo
#       5 for code in est_codes:
# ----> 6     data14 = requests.get('https://apitempo.inmet.gov.br/estacao/diaria/2021-09-16/2021-09-30/'+code)
#       7     dict_14days.update({code:data14.json()})
#       8     list14_days.append(data14.json())
#
# ~/miniconda3/envs/smap/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/miniconda3/envs/smap/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/miniconda3/envs/smap/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/miniconda3/envs/smap/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/miniconda3/envs/smap/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/miniconda3/envs/smap/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~/miniconda3/envs/smap/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         # Trigger any extra validation we need to do.
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#     384             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/miniconda3/envs/smap/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1008         # Force connect early to allow us to validate the connection.
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#    1012         if not conn.is_verified:
#
# ~/miniconda3/envs/smap/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     351     def connect(self):
#     352         # Add certificate verification
# --> 353         conn = self._new_conn()
#     354         hostname = self.host
#     355         tls_in_tls = False
#
# ~/miniconda3/envs/smap/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     167
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#     171             )
#
# ~/miniconda3/envs/smap/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      84             if source_address:
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#      88
#
# KeyboardInterrupt:

# %%
# Para escolha da estação, esta seção
# está listando os códigos das estações que tenham pelo menos o primeiro dia com dado de temperatura mínima
validas = []
for chave in dict_14days.keys():
    if pd.DataFrame(dict_14days[chave])['TEMP_MIN'].isnull()[0] == False:
        validas.append(chave)
validas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-158cd497a32d> in <module>
#       2 # está listando os códigos das estações que tenham pelo menos o primeiro dia com dado de temperatura mínima
#       3 validas = []
# ----> 4 for chave in dict_14days.keys():
#       5     if pd.DataFrame(dict_14days[chave])['TEMP_MIN'].isnull()[0] == False:
#       6         validas.append(chave)
#
# NameError: name 'dict_14days' is not defined

# %%
# supondo o uso da estação a045 seguimos

dataa045 = requests.get('https://apitempo.inmet.gov.br/estacao/diaria/2021-09-16/2021-09-30/A045').json()
dataa756 = requests.get('https://apitempo.inmet.gov.br/estacao/diaria/2021-09-16/2021-09-30/A756').json()

# %%
def df_transform(dictionary):
    df = pd.DataFrame(dictionary)
    df['DT_MEDICAO'] = pd.to_datetime(df['DT_MEDICAO'])
    
    float_cols = ['UMID_MIN', 'TEMP_MED', 'CHUVA','VL_LATITUDE','TEMP_MIN','TEMP_MAX','VEL_VENTO_MED','VL_LONGITUDE','UMID_MED']
    for cada in float_cols:
        df[cada] = df[cada].apply(lambda x: float(x))
        
    return df
    
a756 = df_transform(dataa756)
a045 = df_transform(dataa045)

a045.to_csv('dados_a045.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-0ff1b06f5bac> in <module>
#       9     return df
#      10
# ---> 11 a756 = df_transform(dataa756)
#      12 a045 = df_transform(dataa045)
#      13
#
# <ipython-input-61-0ff1b06f5bac> in df_transform(dictionary)
#       5     float_cols = ['UMID_MIN', 'TEMP_MED', 'CHUVA','VL_LATITUDE','TEMP_MIN','TEMP_MAX','VEL_VENTO_MED','VL_LONGITUDE','UMID_MED']
#       6     for cada in float_cols:
# ----> 7         df[cada] = df[cada].apply(lambda x: float(x))
#       8
#       9     return df
#
# ~/miniconda3/envs/smap/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-61-0ff1b06f5bac> in <lambda>(x)
#       5     float_cols = ['UMID_MIN', 'TEMP_MED', 'CHUVA','VL_LATITUDE','TEMP_MIN','TEMP_MAX','VEL_VENTO_MED','VL_LONGITUDE','UMID_MED']
#       6     for cada in float_cols:
# ----> 7         df[cada] = df[cada].apply(lambda x: float(x))
#       8
#       9     return df
#
# TypeError: float() argument must be a string or a number, not 'NoneType'

# %% [markdown]
# Plot

# %%
pip install cufflinks
# Out:
# Requirement already satisfied: cufflinks in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (0.17.3)
# Requirement already satisfied: colorlover>=0.2.1 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: ipython>=5.3.0 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from cufflinks) (7.21.0)
# Requirement already satisfied: setuptools>=34.4.1 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from cufflinks) (52.0.0.post20210125)
# Requirement already satisfied: pandas>=0.19.2 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from cufflinks) (1.2.3)
# Requirement already satisfied: ipywidgets>=7.0.0 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from cufflinks) (7.6.5)
# Requirement already satisfied: six>=1.9.0 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from cufflinks) (1.15.0)
# Requirement already satisfied: plotly>=4.1.1 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from cufflinks) (4.14.3)
# Requirement already satisfied: numpy>=1.9.2 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from cufflinks) (1.18.1)
# Requirement already satisfied: backcall in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from ipython>=5.3.0->cufflinks) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from ipython>=5.3.0->cufflinks) (0.17.0)
# Requirement already satisfied: pygments in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from ipython>=5.3.0->cufflinks) (2.8.1)
# Requirement already satisfied: decorator in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from ipython>=5.3.0->cufflinks) (4.4.2)
# Requirement already satisfied: traitlets>=4.2 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from ipython>=5.3.0->cufflinks) (5.0.5)
# Requirement already satisfied: pexpect>4.3 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from ipython>=5.3.0->cufflinks) (4.8.0)
# Requirement already satisfied: pickleshare in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from ipython>=5.3.0->cufflinks) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from ipython>=5.3.0->cufflinks) (3.0.17)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from ipywidgets>=7.0.0->cufflinks) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from ipywidgets>=7.0.0->cufflinks) (5.1.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from ipywidgets>=7.0.0->cufflinks) (1.0.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from ipywidgets>=7.0.0->cufflinks) (5.3.4)
# Requirement already satisfied: jupyter-client in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (6.1.7)
# Requirement already satisfied: tornado>=4.2 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (6.1)
# Requirement already satisfied: parso>=0.7.0 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from jedi>=0.16->ipython>=5.3.0->cufflinks) (0.8.1)
# Requirement already satisfied: jupyter-core in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (4.7.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (4.0.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (20.3.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from pandas>=0.19.2->cufflinks) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from pandas>=0.19.2->cufflinks) (2021.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from pexpect>4.3->ipython>=5.3.0->cufflinks) (0.7.0)
# Requirement already satisfied: retrying>=1.3.3 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from plotly>=4.1.1->cufflinks) (1.3.3)
# Requirement already satisfied: wcwidth in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->cufflinks) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (6.4.4)
# Requirement already satisfied: nbconvert in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (6.2.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.12.1)
# Requirement already satisfied: Send2Trash>=1.5.0 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.8.0)
# Requirement already satisfied: prometheus-client in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.11.0)
# Requirement already satisfied: argon2-cffi in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (21.1.0)
# Requirement already satisfied: pyzmq>=17 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (20.0.0)
# Requirement already satisfied: jinja2 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (3.0.1)
# Requirement already satisfied: cffi>=1.0.0 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.14.6)
# Requirement already satisfied: pycparser in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.20)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.0.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.5.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.8.4)
# Requirement already satisfied: defusedxml in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.1.2)
# Requirement already satisfied: testpath in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.5.0)
# Requirement already satisfied: bleach in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (4.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.5.0)
# Requirement already satisfied: nest-asyncio in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.5.1)
# Requirement already satisfied: webencodings in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.5.1)
# Requirement already satisfied: packaging in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (21.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/gabriel/miniconda3/envs/smap/lib/python3.8/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.4.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import cufflinks
import seaborn as sns
sns.set_style('darkgrid')

# %%
init_notebook_mode(connected=True)
cufflinks.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
a045
# Out:
#    UMID_MED DT_MEDICAO          DC_NOME UMID_MIN TEMP_MED CHUVA VL_LATITUDE  \
# 0      28.8 2021-09-16  AGUAS EMENDADAS       13     25.1     0  -15.596491
# 1      30.2 2021-09-17  AGUAS EMENDADAS       16     23.6     0  -15.596491
# 2      35.2 2021-09-18  AGUAS EMENDADAS       12     22.3     0  -15.596491
# 3      23.9 2021-09-19  AGUAS EMENDADAS       10     24.2     0  -15.596491
# 4      33.9 2021-09-20  AGUAS EMENDADAS       14     24.7     0  -15.596491
# 5      36.1 2021-09-21  AGUAS EMENDADAS       12     25.7     0  -15.596491
# 6      40.3 2021-09-22  AGUAS EMENDADAS       13     25.3     0  -15.596491
# 7      48.9 2021-09-23  AGUAS EMENDADAS       29     25.2     0  -15.596491
# 8      50.1 2021-09-24  AGUAS EMENDADAS       19     25.3     0  -15.596491
# 9      61.6 2021-09-25  AGUAS EMENDADAS       30     22.4     0  -15.596491
# 10     61.5 2021-09-26  AGUAS EMENDADAS       33     21.6     0  -15.596491
# 11     51.3 2021-09-27  AGUAS EMENDADAS       20     23.6     0  -15.596491
# 12     41.8 2021-09-28  AGUAS EMENDADAS       20       25     0  -15.596491
# 13     45.6 2021-09-29  AGUAS EMENDADAS       21     25.4     0  -15.596491
# 14     61.8 2021-09-30  AGUAS EMENDADAS       25     23.4   3.4  -15.596491
#
#    TEMP_MIN TEMP_MAX  UF VEL_VENTO_MED CD_ESTACAO VL_LONGITUDE
# 0      15.4     34.1  DF           2.7       A045   -47.625801
# 1      18.8     30.5  DF           3.1       A045   -47.625801
# 2      13.8     32.1  DF           2.3       A045   -47.625801
# 3      10.4     34.3  DF           2.5       A045   -47.625801
# 4      11.5     34.7  DF           2.1       A045   -47.625801
# 5        14     37.1  DF           1.6       A045   -47.625801
# 6      14.7     36.8  DF           1.7       A045   -47.625801
# 7        18     32.9  DF           2.8       A045   -47.625801
# 8      17.2     34.3  DF             2       A045   -47.625801
# 9      19.3       30  DF           1.4       A045   -47.625801
# 10     14.1     30.3  DF             2       A045   -47.625801
# 11     15.9     32.5  DF           2.1       A045   -47.625801
# 12     17.4     32.8  DF             2       A045   -47.625801
# 13     18.8     33.7  DF           1.8       A045   -47.625801
# 14     14.4     33.1  DF           1.2       A045   -47.625801

# %%
conc = pd.concat([a045, a756])

# %%
conc
# Out:
#    UMID_MED DT_MEDICAO          DC_NOME UMID_MIN TEMP_MED CHUVA   VL_LATITUDE  \
# 0      28.8 2021-09-16  AGUAS EMENDADAS       13     25.1     0    -15.596491
# 1      30.2 2021-09-17  AGUAS EMENDADAS       16     23.6     0    -15.596491
# 2      35.2 2021-09-18  AGUAS EMENDADAS       12     22.3     0    -15.596491
# 3      23.9 2021-09-19  AGUAS EMENDADAS       10     24.2     0    -15.596491
# 4      33.9 2021-09-20  AGUAS EMENDADAS       14     24.7     0    -15.596491
# 5      36.1 2021-09-21  AGUAS EMENDADAS       12     25.7     0    -15.596491
# 6      40.3 2021-09-22  AGUAS EMENDADAS       13     25.3     0    -15.596491
# 7      48.9 2021-09-23  AGUAS EMENDADAS       29     25.2     0    -15.596491
# 8      50.1 2021-09-24  AGUAS EMENDADAS       19     25.3     0    -15.596491
# 9      61.6 2021-09-25  AGUAS EMENDADAS       30     22.4     0    -15.596491
# 10     61.5 2021-09-26  AGUAS EMENDADAS       33     21.6     0    -15.596491
# 11     51.3 2021-09-27  AGUAS EMENDADAS       20     23.6     0    -15.596491
# 12     41.8 2021-09-28  AGUAS EMENDADAS       20       25     0    -15.596491
# 13     45.6 2021-09-29  AGUAS EMENDADAS       21     25.4     0    -15.596491
# 14     61.8 2021-09-30  AGUAS EMENDADAS       25     23.4   3.4    -15.596491
# 0      80.2 2021-09-16       ÁGUA CLARA       50       25   2.6  -20.44444444
# 1      59.6 2021-09-17       ÁGUA CLARA       20     27.1     0  -20.44444444
# 2      48.3 2021-09-18       ÁGUA CLARA       13     29.5     0  -20.44444444
# 3      46.1 2021-09-19       ÁGUA CLARA       10     29.9     0  -20.44444444
# 4      39.7 2021-09-20       ÁGUA CLARA        9     30.3     0  -20.44444444
# 5      32.3 2021-09-21       ÁGUA CLARA        9       31     0  -20.44444444
# 6      45.2 2021-09-22       ÁGUA CLARA       21       29     0  -20.44444444
# 7      47.5 2021-09-23       ÁGUA CLARA       24     24.4     0  -20.44444444
# 8      41.9 2021-09-24       ÁGUA CLARA       18     27.2     0  -20.44444444
# 9        40 2021-09-25       ÁGUA CLARA       19     28.7     0  -20.44444444
# 10       58 2021-09-26       ÁGUA CLARA       18     25.9     0  -20.44444444
# 11     62.7 2021-09-27       ÁGUA CLARA       23     26.6    11  -20.44444444
# 12     50.6 2021-09-28       ÁGUA CLARA       19     29.1     0  -20.44444444
# 13     46.8 2021-09-29       ÁGUA CLARA       14     30.6     0  -20.44444444
# 14     43.5 2021-09-30       ÁGUA CLARA       19     30.7     0  -20.44444444
#
#    TEMP_MIN TEMP_MAX  UF VEL_VENTO_MED CD_ESTACAO  VL_LONGITUDE
# 0      15.4     34.1  DF           2.7       A045    -47.625801
# 1      18.8     30.5  DF           3.1       A045    -47.625801
# 2      13.8     32.1  DF           2.3       A045    -47.625801
# 3      10.4     34.3  DF           2.5       A045    -47.625801
# 4      11.5     34.7  DF           2.1       A045    -47.625801
# 5        14     37.1  DF           1.6       A045    -47.625801
# 6      14.7     36.8  DF           1.7       A045    -47.625801
# 7        18     32.9  DF           2.8       A045    -47.625801
# 8      17.2     34.3  DF             2       A045    -47.625801
# 9      19.3       30  DF           1.4       A045    -47.625801
# 10     14.1     30.3  DF             2       A045    -47.625801
# 11     15.9     32.5  DF           2.1       A045    -47.625801
# 12     17.4     32.8  DF             2       A045    -47.625801
# 13     18.8     33.7  DF           1.8       A045    -47.625801
# 14     14.4     33.1  DF           1.2       A045    -47.625801
# 0      20.9     31.1  MS          None       A756  -52.87583332
# 1      19.4     38.2  MS          None       A756  -52.87583332
# 2      19.7     41.1  MS          None       A756  -52.87583332
# 3      19.5     42.3  MS          None       A756  -52.87583332
# 4      18.1     43.2  MS          None       A756  -52.87583332
# 5      20.5     42.7  MS          None       A756  -52.87583332
# 6      23.4       35  MS          None       A756  -52.87583332
# 7      16.6     33.3  MS          None       A756  -52.87583332
# 8      19.1     36.9  MS          None       A756  -52.87583332
# 9      19.9     38.1  MS          None       A756  -52.87583332
# 10     20.1     39.3  MS          None       A756  -52.87583332
# 11     19.7     36.4  MS          None       A756  -52.87583332
# 12     20.3     39.1  MS          None       A756  -52.87583332
# 13     21.8     40.2  MS          None       A756  -52.87583332
# 14     22.2       40  MS          None       A756  -52.87583332

# %%
fig, ax = plt.subplots(1,1, figsize=(10, 10))
sns.scatterplot(x=conc['DT_MEDICAO'], y=conc['TEMP_MED'], hue=conc['DC_NOME'])
# Out:
# <AxesSubplot:xlabel='DT_MEDICAO', ylabel='TEMP_MED'>

# %%
fig, ax = plt.subplots(1,1, figsize=(10, 10))
ax.plot(a045['DT_MEDICAO'], a045['TEMP_MIN'])
ax.plot(a756['DT_MEDICAO'], a756['TEMP_MIN'])

# %% [markdown]
# ## Falhas nos dados
#
# Procurando por valores Nulos e espúrios

# %% [markdown]
# 1) Observando o mapa de calor para dados nulos:

# %%
sns.heatmap(a045.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(a756.isnull())
# observa-se que durante o intervalo de 14 dias, a velocidade do vento não foi medida nessa estação
# Out:
# <AxesSubplot:>

# %%
float_cols = ['UMID_MIN', 'TEMP_MED', 'CHUVA','VL_LATITUDE','TEMP_MIN','TEMP_MAX','VEL_VENTO_MED','VL_LONGITUDE','UMID_MED']
for cada in float_cols:
    a045[cada] = a045[cada].apply(lambda x: float(x))

# %%
outliers_index = []
for col in float_cols:
    for cada in a045[col]:
        mean = a045[col].mean()
        dif = float(cada) - float(mean)
        if math.fabs(dif) > 100:
            # listando index questionáveis:
            outliers_index.append(a045.where(a045[col]==cada).dropna().index)
